# %%
from env import config
from sqlalchemy import create_engine, text

# %%
DATABASE_URL= config("DATABASE_URL")
DATABASE_URL is not None
# Out:
# True

# %%
engine = create_engine(str(DATABASE_URL))

# %%
import io
import requests
import pandas as pd


#1LIvIdqdHDFEGnfzIgEh4L6GFirzsE3US
file_id = "1LIvIdqdHDFEGnfzIgEh4L6GFirzsE3US"
url = f"https://drive.google.com/uc?id={file_id}"

# Download the contents of the CSV file
download = requests.get(url).content

# Read the CSV file into a Pandas DataFrame
df = pd.read_csv(io.StringIO(download.decode("utf-8")))

# %%
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.count()
# Out:
# Loan_ID              598
# Gender               598
# Married              598
# Dependents           586
# Education            598
# Self_Employed        598
# ApplicantIncome      598
# CoapplicantIncome    598
# LoanAmount           577
# Loan_Amount_Term     584
# Credit_History       549
# Property_Area        598
# Loan_Status          598
# dtype: int64

# %%
df.describe()
# Out:
#        Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  586.000000       598.000000         598.000000  577.000000
# mean     0.755973      5292.252508        1631.499866  144.968804
# std      1.007751      5807.265364        2953.315785   82.704182
# min      0.000000       150.000000           0.000000    9.000000
# 25%      0.000000      2877.500000           0.000000  100.000000
# 50%      0.000000      3806.000000        1211.500000  127.000000
# 75%      1.750000      5746.000000        2324.000000  167.000000
# max      3.000000     81000.000000       41667.000000  650.000000
#
#        Loan_Amount_Term  Credit_History
# count        584.000000      549.000000
# mean         341.917808        0.843352
# std           65.205994        0.363800
# min           12.000000        0.000000
# 25%          360.000000        1.000000
# 50%          360.000000        1.000000
# 75%          360.000000        1.000000
# max          480.000000        1.000000

# %%
# Drop the incomplete rows
df.dropna(inplace= True)

# %%
df.count()
# Out:
# Loan_ID              505
# Gender               505
# Married              505
# Dependents           505
# Education            505
# Self_Employed        505
# ApplicantIncome      505
# CoapplicantIncome    505
# LoanAmount           505
# Loan_Amount_Term     505
# Credit_History       505
# Property_Area        505
# Loan_Status          505
# dtype: int64

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents           float64
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
# Convert columns to the correct data types
df["Gender"] = df["Gender"].astype(str)
df["Married"] = df["Married"].astype(str)
df["Education"] = df["Education"].astype(str)
df["Property_Area"] = df["Property_Area"].astype(str)
df["Self_Employed"] = df["Self_Employed"].astype(str)

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents           float64
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
# Display unique values in specified columns
print("Unique values in 'Gender':", df['Gender'].unique())
print("Unique values in 'Married':", df['Married'].unique())
print("Unique values in 'Education':", df['Education'].unique())
print("Unique values in 'Self_Employed':", df['Self_Employed'].unique())
print("Unique values in 'Property_Area':", df['Property_Area'].unique())
# Out:
# Unique values in 'Gender': ['Male' 'Female']
# Unique values in 'Married': ['Yes' 'No']
# Unique values in 'Education': ['Graduate' 'Not Graduate']
# Unique values in 'Self_Employed': ['No' 'Yes']
# Unique values in 'Property_Area': ['Rural' 'Urban' 'Semiurban']

# %%
# Exclude the Loan_ID collumn
# df.drop(columns = ["Loan_ID"], inplace = True)

# %%
df
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes         1.0      Graduate            No
# 2    LP001005    Male     Yes         0.0      Graduate           Yes
# 3    LP001006    Male     Yes         0.0  Not Graduate            No
# 4    LP001008    Male      No         0.0      Graduate            No
# 5    LP001011    Male     Yes         2.0      Graduate           Yes
# ..        ...     ...     ...         ...           ...           ...
# 593  LP002978  Female      No         0.0      Graduate            No
# 594  LP002979    Male     Yes         3.0      Graduate            No
# 595  LP002983    Male     Yes         1.0      Graduate            No
# 596  LP002984    Male     Yes         2.0      Graduate            No
# 597  LP002990  Female      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 5               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 593             2900                0.0        71.0             360.0
# 594             4106                0.0        40.0             180.0
# 595             8072              240.0       253.0             360.0
# 596             7583                0.0       187.0             360.0
# 597             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# 5               1.0         Urban           Y
# ..              ...           ...         ...
# 593             1.0         Rural           Y
# 594             1.0         Rural           Y
# 595             1.0         Urban           Y
# 596             1.0         Urban           Y
# 597             0.0     Semiurban           N
#
# [505 rows x 13 columns]

# %%
out_df = df.copy()

# %%
out_df.insert(12,'Email','biplabbera60@gmail.com')
out_df
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes         1.0      Graduate            No
# 2    LP001005    Male     Yes         0.0      Graduate           Yes
# 3    LP001006    Male     Yes         0.0  Not Graduate            No
# 4    LP001008    Male      No         0.0      Graduate            No
# 5    LP001011    Male     Yes         2.0      Graduate           Yes
# ..        ...     ...     ...         ...           ...           ...
# 593  LP002978  Female      No         0.0      Graduate            No
# 594  LP002979    Male     Yes         3.0      Graduate            No
# 595  LP002983    Male     Yes         1.0      Graduate            No
# 596  LP002984    Male     Yes         2.0      Graduate            No
# 597  LP002990  Female      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 5               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 593             2900                0.0        71.0             360.0
# 594             4106                0.0        40.0             180.0
# 595             8072              240.0       253.0             360.0
# 596             7583                0.0       187.0             360.0
# 597             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area                   Email Loan_Status
# 1               1.0         Rural  biplabbera60@gmail.com           N
# 2               1.0         Urban  biplabbera60@gmail.com           Y
# 3               1.0         Urban  biplabbera60@gmail.com           Y
# 4               1.0         Urban  biplabbera60@gmail.com           Y
# 5               1.0         Urban  biplabbera60@gmail.com           Y
# ..              ...           ...                     ...         ...
# 593             1.0         Rural  biplabbera60@gmail.com           Y
# 594             1.0         Rural  biplabbera60@gmail.com           Y
# 595             1.0         Urban  biplabbera60@gmail.com           Y
# 596             1.0         Urban  biplabbera60@gmail.com           Y
# 597             0.0     Semiurban  biplabbera60@gmail.com           N
#
# [505 rows x 14 columns]

# %%
table_name = "loan_data"
out_df.to_sql(table_name, engine, if_exists = "replace", index = False)
# Out:
# 505

# %%
with engine.connect() as conn:
    results = conn.execute(text(f"SELECT * from {table_name} LIMIT 10"))
    print(results.all())
# Out:
# [('LP001003', 'Male', 'Yes', 1.0, 'Graduate', 'No', 4583, 1508.0, 128.0, 360.0, 1.0, 'Rural', 'biplabbera60@gmail.com', 'N'), ('LP001005', 'Male', 'Yes', 0.0, 'Graduate', 'Yes', 3000, 0.0, 66.0, 360.0, 1.0, 'Urban', 'biplabbera60@gmail.com', 'Y'), ('LP001006', 'Male', 'Yes', 0.0, 'Not Graduate', 'No', 2583, 2358.0, 120.0, 360.0, 1.0, 'Urban', 'biplabbera60@gmail.com', 'Y'), ('LP001008', 'Male', 'No', 0.0, 'Graduate', 'No', 6000, 0.0, 141.0, 360.0, 1.0, 'Urban', 'biplabbera60@gmail.com', 'Y'), ('LP001011', 'Male', 'Yes', 2.0, 'Graduate', 'Yes', 5417, 4196.0, 267.0, 360.0, 1.0, 'Urban', 'biplabbera60@gmail.com', 'Y'), ('LP001013', 'Male', 'Yes', 0.0, 'Not Graduate', 'No', 2333, 1516.0, 95.0, 360.0, 1.0, 'Urban', 'biplabbera60@gmail.com', 'Y'), ('LP001014', 'Male', 'Yes', 3.0, 'Graduate', 'No', 3036, 2504.0, 158.0, 360.0, 0.0, 'Semiurban', 'biplabbera60@gmail.com', 'N'), ('LP001018', 'Male', 'Yes', 2.0, 'Graduate', 'No', 4006, 1526.0, 168.0, 360.0, 1.0, 'Urban', 'biplabbera60@gmail.com', 'Y'), ('LP001020', 'Male', 'Yes', 1.0, 'Graduate', 'No', 12841, 10968.0, 349.0, 360.0, 1.0, 'Semiurban', 'biplabbera60@gmail.com', 'N'), ('LP001024', 'Male', 'Yes', 2.0, 'Graduate', 'No', 3200, 700.0, 70.0, 360.0, 1.0, 'Urban', 'biplabbera60@gmail.com', 'Y')]
